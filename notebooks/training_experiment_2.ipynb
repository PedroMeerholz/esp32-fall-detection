# %%
import pandas as pd
from keras.optimizers import Adam
from keras.models import Sequential
from keras.losses import BinaryFocalCrossentropy
from keras.metrics import BinaryAccuracy, Precision, Recall, F1Score
from keras.layers import Dense, Dropout, BatchNormalization, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %%
SEED = 42
INITIAL_LR = 0.01
FINAL_LR = 0.0001
BATCH_SIZE = 64
MODEL_DIR = 'C:\\Users\\meerh\\OneDrive\\Documentos\\Projetos\\esp32-fall-detection\\models'

# %%
df = pd.read_csv('C:\\Users\\meerh\\OneDrive\\Documentos\\Projetos\\esp32-fall-detection\\data\\processed\\acc_gyr.csv')
df.shape
# Out:
# (96800, 7)

# %%
df.head()
# Out:
#    xAcc  yAcc  zAcc  xGyro  yGyro  zGyro  label
# 0  6.99 -0.57 -7.28  -2.75  -3.23   2.62      1
# 1  6.51 -0.75 -6.93  -0.67  -6.35   4.64      1
# 2  6.22 -0.63 -6.73   0.79  -5.49   3.85      1
# 3  6.34 -0.62 -6.80   1.59  -2.26   0.67      1
# 4  6.49 -0.39 -6.60   0.67  -0.24  -1.10      1

# %%
df['label'].value_counts()
# Out:
# label
# 0    68800
# 1    28000
# Name: count, dtype: int64

# %% [markdown]
# # Treino, Teste e Validação

# %%
X = df.drop('label', axis=1)
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED, stratify=y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=SEED, stratify=y_test)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((67760, 6), (67760,), (14520, 6), (14520,), (14520, 6), (14520,))

# %% [markdown]
# # Arquiteura da Rede Neural

# %%
model = Sequential([
    InputLayer(shape=(X_train.shape[1],)),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    BatchNormalization(),
    
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    BatchNormalization(),

    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.15),

    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    BatchNormalization(),
    Dropout(0.15),

    Dense(1, activation='sigmoid'),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1024)           │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 709,921 (2.71 MB)
#  Trainable params: 708,561 (2.70 MB)
#  Non-trainable params: 1,360 (5.31 KB)

# %%
optimizer = Adam(learning_rate=INITIAL_LR)
loss_function = BinaryFocalCrossentropy(alpha=1, gamma=5)
metrics=[BinaryAccuracy(name='accuracy'), Precision(), Recall(), F1Score()]

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# # Treinamento do Modelo

# %%
callbacks = [
    EarlyStopping(monitor='val_recall', patience=20, restore_best_weights=True, mode='max'),
    ModelCheckpoint(f'{MODEL_DIR}/best_model_exp2.keras', monitor='val_recall', save_best_only=True, verbose=1, mode='max'),
    ReduceLROnPlateau(monitor='val_recall', factor=0.5, patience=4, min_lr=FINAL_LR, verbose=1, mode='max')
]

# %%
import numpy as np
from sklearn.utils import class_weight
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
weights = dict(enumerate(weights))
weights
# Out:
# {0: np.float64(0.7034883720930233), 1: np.float64(1.7285714285714286)}

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    class_weight=weights
)
# Out:
# Epoch 1/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7569 - f1_score: 0.4491 - loss: 0.0206 - precision: 0.5834 - recall: 0.5943
# Epoch 1: val_recall improved from None to 0.58738, saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
#
# Epoch 1: finished saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.7892 - f1_score: 0.4487 - loss: 0.0172 - precision: 0.6427 - recall: 0.6109 - val_accuracy: 0.8495 - val_f1_score: 0.4487 - val_loss: 0.0148 - val_precision: 0.8452 - val_recall: 0.5874 - learning_rate: 0.0100
# Epoch 2/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8083 - f1_score: 0.4494 - loss: 0.0160 - precision: 0.6845 - recall: 0.6279
# Epoch 2: val_recall improved from 0.58738 to 0.74857, saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
#
# Epoch 2: finished saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 48s 20ms/step - accuracy: 0.8092 - f1_score: 0.4487 - loss: 0.0160 - precision: 0.6850 - recall: 0.6299 - val_accuracy: 0.7626 - val_f1_score: 0.4487 - val_loss: 0.0164 - val_precision: 0.5680 - val_recall: 0.7486 - learning_rate: 0.0100
# Epoch 3/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8141 - f1_score: 0.4467 - loss: 0.0157 - precision: 0.6951 - recall: 0.6303
# Epoch 3: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 45s 21ms/step - accuracy: 0.8112 - f1_score: 0.4487 - loss: 0.0158 - precision: 0.6905 - recall: 0.6292 - val_accuracy: 0.8295 - val_f1_score: 0.4487 - val_loss: 0.0162 - val_precision: 0.7324 - val_recall: 0.6471 - learning_rate: 0.0100
# Epoch 4/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8139 - f1_score: 0.4465 - loss: 0.0159 - precision: 0.6996 - recall: 0.6195
# Epoch 4: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - accuracy: 0.8121 - f1_score: 0.4487 - loss: 0.0158 - precision: 0.6945 - recall: 0.6257 - val_accuracy: 0.8514 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.8702 - val_recall: 0.5717 - learning_rate: 0.0100
# Epoch 5/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8084 - f1_score: 0.4462 - loss: 0.0158 - precision: 0.6807 - recall: 0.6269
# Epoch 5: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 43s 20ms/step - accuracy: 0.8095 - f1_score: 0.4487 - loss: 0.0158 - precision: 0.6861 - recall: 0.6295 - val_accuracy: 0.8080 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.6668 - val_recall: 0.6719 - learning_rate: 0.0100
# Epoch 6/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8063 - f1_score: 0.4485 - loss: 0.0157 - precision: 0.6761 - recall: 0.6341
# Epoch 6: val_recall did not improve from 0.74857
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 38s 18ms/step - accuracy: 0.8093 - f1_score: 0.4487 - loss: 0.0157 - precision: 0.6828 - recall: 0.6363 - val_accuracy: 0.8344 - val_f1_score: 0.4487 - val_loss: 0.0155 - val_precision: 0.7540 - val_recall: 0.6343 - learning_rate: 0.0100
# Epoch 7/100
# 2113/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8096 - f1_score: 0.4496 - loss: 0.0154 - precision: 0.6771 - recall: 0.6565
# Epoch 7: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8112 - f1_score: 0.4487 - loss: 0.0153 - precision: 0.6814 - recall: 0.6522 - val_accuracy: 0.8108 - val_f1_score: 0.4487 - val_loss: 0.0154 - val_precision: 0.6643 - val_recall: 0.6995 - learning_rate: 0.0050
# Epoch 8/100
# 2114/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8113 - f1_score: 0.4504 - loss: 0.0152 - precision: 0.6823 - recall: 0.6573
# Epoch 8: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.8122 - f1_score: 0.4487 - loss: 0.0151 - precision: 0.6832 - recall: 0.6538 - val_accuracy: 0.8255 - val_f1_score: 0.4487 - val_loss: 0.0154 - val_precision: 0.7092 - val_recall: 0.6724 - learning_rate: 0.0050
# Epoch 9/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8078 - f1_score: 0.4481 - loss: 0.0152 - precision: 0.6739 - recall: 0.6481
# Epoch 9: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.8103 - f1_score: 0.4487 - loss: 0.0151 - precision: 0.6802 - recall: 0.6500 - val_accuracy: 0.8123 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.6689 - val_recall: 0.6950 - learning_rate: 0.0050
# Epoch 10/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8159 - f1_score: 0.4519 - loss: 0.0151 - precision: 0.6939 - recall: 0.6611
# Epoch 10: val_recall did not improve from 0.74857
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.8140 - f1_score: 0.4487 - loss: 0.0150 - precision: 0.6869 - recall: 0.6562 - val_accuracy: 0.8114 - val_f1_score: 0.4487 - val_loss: 0.0164 - val_precision: 0.6667 - val_recall: 0.6960 - learning_rate: 0.0050
# Epoch 11/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8200 - f1_score: 0.4473 - loss: 0.0147 - precision: 0.6963 - recall: 0.6658
# Epoch 11: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.8159 - f1_score: 0.4487 - loss: 0.0148 - precision: 0.6886 - recall: 0.6640 - val_accuracy: 0.8356 - val_f1_score: 0.4487 - val_loss: 0.0144 - val_precision: 0.7391 - val_recall: 0.6671 - learning_rate: 0.0025
# Epoch 12/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8167 - f1_score: 0.4463 - loss: 0.0145 - precision: 0.6843 - recall: 0.6725
# Epoch 12: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 28s 13ms/step - accuracy: 0.8132 - f1_score: 0.4487 - loss: 0.0146 - precision: 0.6790 - recall: 0.6716 - val_accuracy: 0.8331 - val_f1_score: 0.4487 - val_loss: 0.0149 - val_precision: 0.7335 - val_recall: 0.6645 - learning_rate: 0.0025
# Epoch 13/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8153 - f1_score: 0.4488 - loss: 0.0146 - precision: 0.6834 - recall: 0.6738
# Epoch 13: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 25s 12ms/step - accuracy: 0.8160 - f1_score: 0.4487 - loss: 0.0146 - precision: 0.6863 - recall: 0.6703 - val_accuracy: 0.8304 - val_f1_score: 0.4487 - val_loss: 0.0140 - val_precision: 0.7261 - val_recall: 0.6645 - learning_rate: 0.0025
# Epoch 14/100
# 2112/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8152 - f1_score: 0.4514 - loss: 0.0145 - precision: 0.6851 - recall: 0.6777
# Epoch 14: val_recall did not improve from 0.74857
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8158 - f1_score: 0.4487 - loss: 0.0145 - precision: 0.6840 - recall: 0.6749 - val_accuracy: 0.8202 - val_f1_score: 0.4487 - val_loss: 0.0144 - val_precision: 0.6843 - val_recall: 0.7029 - learning_rate: 0.0025
# Epoch 15/100
# 2113/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8178 - f1_score: 0.4469 - loss: 0.0144 - precision: 0.6858 - recall: 0.6768
# Epoch 15: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - accuracy: 0.8164 - f1_score: 0.4487 - loss: 0.0144 - precision: 0.6837 - recall: 0.6795 - val_accuracy: 0.8085 - val_f1_score: 0.4487 - val_loss: 0.0145 - val_precision: 0.6536 - val_recall: 0.7193 - learning_rate: 0.0012
# Epoch 16/100
# 2113/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8163 - f1_score: 0.4482 - loss: 0.0141 - precision: 0.6819 - recall: 0.6835
# Epoch 16: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.8190 - f1_score: 0.4487 - loss: 0.0142 - precision: 0.6902 - recall: 0.6789 - val_accuracy: 0.8140 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.6671 - val_recall: 0.7129 - learning_rate: 0.0012
# Epoch 17/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8167 - f1_score: 0.4494 - loss: 0.0141 - precision: 0.6853 - recall: 0.6803
# Epoch 17: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.8184 - f1_score: 0.4487 - loss: 0.0142 - precision: 0.6889 - recall: 0.6784 - val_accuracy: 0.8382 - val_f1_score: 0.4487 - val_loss: 0.0148 - val_precision: 0.7465 - val_recall: 0.6669 - learning_rate: 0.0012
# Epoch 18/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8237 - f1_score: 0.4462 - loss: 0.0142 - precision: 0.6961 - recall: 0.6856
# Epoch 18: val_recall did not improve from 0.74857
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - accuracy: 0.8191 - f1_score: 0.4487 - loss: 0.0142 - precision: 0.6865 - recall: 0.6896 - val_accuracy: 0.8405 - val_f1_score: 0.4487 - val_loss: 0.0166 - val_precision: 0.7578 - val_recall: 0.6593 - learning_rate: 0.0012
# Epoch 19/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8193 - f1_score: 0.4509 - loss: 0.0140 - precision: 0.6901 - recall: 0.6883
# Epoch 19: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8212 - f1_score: 0.4487 - loss: 0.0140 - precision: 0.6937 - recall: 0.6839 - val_accuracy: 0.8361 - val_f1_score: 0.4487 - val_loss: 0.0143 - val_precision: 0.7369 - val_recall: 0.6740 - learning_rate: 6.2500e-04
# Epoch 20/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8200 - f1_score: 0.4459 - loss: 0.0141 - precision: 0.6892 - recall: 0.6786
# Epoch 20: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8220 - f1_score: 0.4487 - loss: 0.0141 - precision: 0.6955 - recall: 0.6845 - val_accuracy: 0.8180 - val_f1_score: 0.4487 - val_loss: 0.0154 - val_precision: 0.6761 - val_recall: 0.7121 - learning_rate: 6.2500e-04
# Epoch 21/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8205 - f1_score: 0.4482 - loss: 0.0141 - precision: 0.6893 - recall: 0.6896
# Epoch 21: val_recall did not improve from 0.74857
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8210 - f1_score: 0.4487 - loss: 0.0140 - precision: 0.6909 - recall: 0.6898 - val_accuracy: 0.8395 - val_f1_score: 0.4487 - val_loss: 0.0140 - val_precision: 0.7465 - val_recall: 0.6738 - learning_rate: 6.2500e-04
# Epoch 22/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8208 - f1_score: 0.4463 - loss: 0.0139 - precision: 0.6848 - recall: 0.6977
# Epoch 22: val_recall improved from 0.74857 to 0.75619, saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
#
# Epoch 22: finished saving model to C:\Users\meerh\OneDrive\Documentos\Projetos\esp32-fall-detection\models/best_model_exp2.keras
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.8217 - f1_score: 0.4487 - loss: 0.0140 - precision: 0.6910 - recall: 0.6938 - val_accuracy: 0.7925 - val_f1_score: 0.4487 - val_loss: 0.0148 - val_precision: 0.6149 - val_recall: 0.7562 - learning_rate: 6.2500e-04
# Epoch 23/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8233 - f1_score: 0.4466 - loss: 0.0138 - precision: 0.6926 - recall: 0.6931
# Epoch 23: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 28s 13ms/step - accuracy: 0.8216 - f1_score: 0.4487 - loss: 0.0139 - precision: 0.6910 - recall: 0.6934 - val_accuracy: 0.8282 - val_f1_score: 0.4487 - val_loss: 0.0141 - val_precision: 0.7063 - val_recall: 0.6950 - learning_rate: 6.2500e-04
# Epoch 24/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8206 - f1_score: 0.4514 - loss: 0.0140 - precision: 0.6928 - recall: 0.6908
# Epoch 24: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8225 - f1_score: 0.4487 - loss: 0.0139 - precision: 0.6936 - recall: 0.6919 - val_accuracy: 0.8378 - val_f1_score: 0.4487 - val_loss: 0.0142 - val_precision: 0.7430 - val_recall: 0.6717 - learning_rate: 6.2500e-04
# Epoch 25/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8220 - f1_score: 0.4479 - loss: 0.0138 - precision: 0.6896 - recall: 0.6976
# Epoch 25: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8200 - f1_score: 0.4487 - loss: 0.0139 - precision: 0.6856 - recall: 0.6978 - val_accuracy: 0.8097 - val_f1_score: 0.4487 - val_loss: 0.0143 - val_precision: 0.6554 - val_recall: 0.7214 - learning_rate: 6.2500e-04
# Epoch 26/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8186 - f1_score: 0.4471 - loss: 0.0142 - precision: 0.6817 - recall: 0.6942
# Epoch 26: val_recall did not improve from 0.75619
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.8205 - f1_score: 0.4487 - loss: 0.0139 - precision: 0.6873 - recall: 0.6965 - val_accuracy: 0.8211 - val_f1_score: 0.4487 - val_loss: 0.0144 - val_precision: 0.6863 - val_recall: 0.7026 - learning_rate: 6.2500e-04
# Epoch 27/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8207 - f1_score: 0.4476 - loss: 0.0139 - precision: 0.6892 - recall: 0.6891
# Epoch 27: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8222 - f1_score: 0.4487 - loss: 0.0138 - precision: 0.6916 - recall: 0.6950 - val_accuracy: 0.8357 - val_f1_score: 0.4487 - val_loss: 0.0151 - val_precision: 0.7326 - val_recall: 0.6805 - learning_rate: 3.1250e-04
# Epoch 28/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8274 - f1_score: 0.4475 - loss: 0.0137 - precision: 0.7029 - recall: 0.6956
# Epoch 28: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8244 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6963 - recall: 0.6969 - val_accuracy: 0.8121 - val_f1_score: 0.4487 - val_loss: 0.0145 - val_precision: 0.6575 - val_recall: 0.7317 - learning_rate: 3.1250e-04
# Epoch 29/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8238 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6912 - recall: 0.7068
# Epoch 29: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8234 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6914 - recall: 0.7035 - val_accuracy: 0.8193 - val_f1_score: 0.4487 - val_loss: 0.0155 - val_precision: 0.6780 - val_recall: 0.7148 - learning_rate: 3.1250e-04
# Epoch 30/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8203 - f1_score: 0.4543 - loss: 0.0139 - precision: 0.6904 - recall: 0.7043
# Epoch 30: val_recall did not improve from 0.75619
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.8236 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6921 - recall: 0.7027 - val_accuracy: 0.8348 - val_f1_score: 0.4487 - val_loss: 0.0142 - val_precision: 0.7286 - val_recall: 0.6838 - learning_rate: 3.1250e-04
# Epoch 31/100
# 2114/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8245 - f1_score: 0.4485 - loss: 0.0137 - precision: 0.6983 - recall: 0.6919
# Epoch 31: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8253 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6976 - recall: 0.6990 - val_accuracy: 0.8276 - val_f1_score: 0.4487 - val_loss: 0.0143 - val_precision: 0.7044 - val_recall: 0.6962 - learning_rate: 1.5625e-04
# Epoch 32/100
# 2112/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8242 - f1_score: 0.4489 - loss: 0.0136 - precision: 0.6932 - recall: 0.7045
# Epoch 32: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8223 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6899 - recall: 0.7006 - val_accuracy: 0.8181 - val_f1_score: 0.4487 - val_loss: 0.0146 - val_precision: 0.6757 - val_recall: 0.7138 - learning_rate: 1.5625e-04
# Epoch 33/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8245 - f1_score: 0.4508 - loss: 0.0137 - precision: 0.6972 - recall: 0.7021
# Epoch 33: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8241 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6932 - recall: 0.7030 - val_accuracy: 0.8249 - val_f1_score: 0.4487 - val_loss: 0.0146 - val_precision: 0.6968 - val_recall: 0.6988 - learning_rate: 1.5625e-04
# Epoch 34/100
# 2112/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8250 - f1_score: 0.4494 - loss: 0.0137 - precision: 0.6982 - recall: 0.6979
# Epoch 34: val_recall did not improve from 0.75619
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001.
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8238 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6930 - recall: 0.7018 - val_accuracy: 0.8101 - val_f1_score: 0.4487 - val_loss: 0.0152 - val_precision: 0.6535 - val_recall: 0.7307 - learning_rate: 1.5625e-04
# Epoch 35/100
# 2114/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8257 - f1_score: 0.4475 - loss: 0.0136 - precision: 0.6914 - recall: 0.7146
# Epoch 35: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8235 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6905 - recall: 0.7064 - val_accuracy: 0.8198 - val_f1_score: 0.4487 - val_loss: 0.0150 - val_precision: 0.6803 - val_recall: 0.7112 - learning_rate: 1.0000e-04
# Epoch 36/100
# 2116/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8238 - f1_score: 0.4464 - loss: 0.0138 - precision: 0.6909 - recall: 0.7001
# Epoch 36: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8248 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6952 - recall: 0.7022 - val_accuracy: 0.8196 - val_f1_score: 0.4487 - val_loss: 0.0144 - val_precision: 0.6800 - val_recall: 0.7110 - learning_rate: 1.0000e-04
# Epoch 37/100
# 2115/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8204 - f1_score: 0.4506 - loss: 0.0137 - precision: 0.6868 - recall: 0.7032
# Epoch 37: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8236 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6922 - recall: 0.7025 - val_accuracy: 0.8174 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.6733 - val_recall: 0.7160 - learning_rate: 1.0000e-04
# Epoch 38/100
# 2111/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8273 - f1_score: 0.4474 - loss: 0.0135 - precision: 0.6981 - recall: 0.7062
# Epoch 38: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8264 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6982 - recall: 0.7040 - val_accuracy: 0.8094 - val_f1_score: 0.4487 - val_loss: 0.0149 - val_precision: 0.6529 - val_recall: 0.7283 - learning_rate: 1.0000e-04
# Epoch 39/100
# 2114/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8230 - f1_score: 0.4477 - loss: 0.0136 - precision: 0.6906 - recall: 0.7000
# Epoch 39: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8251 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6954 - recall: 0.7036 - val_accuracy: 0.8247 - val_f1_score: 0.4487 - val_loss: 0.0151 - val_precision: 0.6955 - val_recall: 0.7010 - learning_rate: 1.0000e-04
# Epoch 40/100
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8271 - f1_score: 0.4506 - loss: 0.0136 - precision: 0.7019 - recall: 0.7050
# Epoch 40: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8247 - f1_score: 0.4487 - loss: 0.0137 - precision: 0.6943 - recall: 0.7041 - val_accuracy: 0.8272 - val_f1_score: 0.4487 - val_loss: 0.0145 - val_precision: 0.7025 - val_recall: 0.6983 - learning_rate: 1.0000e-04
# Epoch 41/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8278 - f1_score: 0.4453 - loss: 0.0135 - precision: 0.6980 - recall: 0.7029
# Epoch 41: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8237 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6919 - recall: 0.7038 - val_accuracy: 0.8126 - val_f1_score: 0.4487 - val_loss: 0.0148 - val_precision: 0.6617 - val_recall: 0.7205 - learning_rate: 1.0000e-04
# Epoch 42/100
# 2117/2118 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8256 - f1_score: 0.4491 - loss: 0.0137 - precision: 0.6970 - recall: 0.7037
# Epoch 42: val_recall did not improve from 0.75619
# 2118/2118 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8258 - f1_score: 0.4487 - loss: 0.0136 - precision: 0.6969 - recall: 0.7039 - val_accuracy: 0.8111 - val_f1_score: 0.4487 - val_loss: 0.0147 - val_precision: 0.6556 - val_recall: 0.7307 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt

def plot_recall(history):
    recall = history.history['recall']
    val_recall = history.history['val_recall']
    
    # Define o eixo X (número de épocas)
    epochs = range(1, len(recall) + 1)

    # Configura o tamanho da figura para melhor visualização
    plt.figure(figsize=(10, 6))

    # Plota as linhas de treinamento e validação
    plt.plot(epochs, recall, 'b-', label='Treinamento (Recall)', linewidth=2)
    plt.plot(epochs, val_recall, 'r--', label='Validação (Val_Recall)', linewidth=2)

    # Personaliza títulos e rótulos
    plt.title('Desempenho do Modelo: Recall por Época', fontsize=16, pad=15)
    plt.xlabel('Épocas', fontsize=14)
    plt.ylabel('Recall', fontsize=14)

    # Adiciona uma grade de fundo para facilitar a leitura dos valores
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Adiciona a legenda no canto inferior direito
    plt.legend(loc='lower right', fontsize=12)

    # Ajusta o layout e exibe o gráfico
    plt.tight_layout()
    plt.show()

# %%
plot_recall(history)
